# %% [markdown]
# # Data Cleaning Notebook – Wine Quality Dataset
#
# ## 1. Introduction
# This notebook presents the data cleaning process applied to the Wine Quality dataset. The aim is to prepare the data for reliable statistical analysis and machine learning tasks.

# %% [markdown]
# ## 2. Data Loading

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv', sep=';')

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## 3. Initial Data Inspection

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...

# %% [markdown]
# ## 4. Missing Values Check

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## 5. Duplicate Records

# %%
df.duplicated().sum()

df = df.drop_duplicates()

# %% [markdown]
# ## 6. Data Validity and Range Checks

# %%
df[['pH', 'alcohol', 'density']].describe()

assert df['pH'].between(0, 14).all()
assert (df['alcohol'] > 0).all()

# %% [markdown]
# ## 7. Outlier Detection

# %%
import matplotlib.pyplot as plt

df.boxplot(figsize=(15,6))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 8. Outlier Treatment

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df_clean = df.clip(
    lower=Q1 - 1.5 * IQR,
    upper=Q3 + 1.5 * IQR,
    axis=1
)

# %% [markdown]
# ## 9. Final Cleaned Dataset Overview

# %%
df_clean.info()

df_clean.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   float64
# dtypes: float64(12)
# memory usage: 138.0 KB
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...
